# %%
import pandas as pd
import numpy as np

normal=pd.read_csv('Normal.csv')
normal.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4    45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal

# %%
Type_H=pd.read_csv('Type_H.csv')
Type_H.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400  Type_H
# 1    39.056951  10.060991  25.015378  28.995960  114.405425   4.564259  Type_H
# 2    68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317  Type_H
# 3    69.297008  24.652878  44.311238  44.644130  101.868495  11.211523  Type_H
# 4    49.712859   9.652075  28.317406  40.060784  108.168725   7.918501  Type_H

# %%
Type_S=pd.read_csv('Type_S.csv')
Type_S.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    74.377678  32.053104  78.772013  42.324573  143.560690  56.125906  Type_S
# 1    89.680567  32.704435  83.130732  56.976132  129.955476  92.027277  Type_S
# 2    44.529051   9.433234  52.000000  35.095817  134.711772  29.106575  Type_S
# 3    77.690577  21.380645  64.429442  56.309932  114.818751  26.931841  Type_S
# 4    76.147212  21.936186  82.961502  54.211027  123.932010  10.431972  Type_S

# %%
print(normal.shape)
print(Type_H.shape)
print(Type_S.shape)
# Out:
# (100, 7)
# (60, 7)
# (150, 7)

# %% [markdown]
# # Merging of data

# %% [raw]
# df=normal.append([Type_S,Type_H])
# df.sample(n=5)

# %% [markdown]
# # Data cleansing:

# %%
df.shape
# Out:
# (310, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  310 non-null    float64
#  1   P_tilt       310 non-null    float64
#  2   L_angle      310 non-null    float64
#  3   S_slope      310 non-null    float64
#  4   P_radius     310 non-null    float64
#  5   S_Degree     310 non-null    float64
#  6   Class        310 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 19.4+ KB

# %%
df.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
df.isna().sum()
# Out:
# P_incidence    0
# P_tilt         0
# L_angle        0
# S_slope        0
# P_radius       0
# S_Degree       0
# Class          0
# dtype: int64

# %%
df.duplicated().sum()
#No duplicate in the data
# Out:
# 0

# %%
df['Class'].value_counts()
# Out:
# Type_S    133
# Normal     73
# Type_H     37
# Nrmal      27
# type_h     23
# tp_s       17
# Name: Class, dtype: int64

# %%
df.loc[df['Class']=='tp_s','Class']='Type_S'
df.loc[df['Class']=='Nrmal','Class']='Normal'
df.loc[df['Class']=='type_h','Class']='Type_H'

# %%
df.describe(include='object')
# Out:
#          Class
# count      310
# unique       3
# top     Type_S
# freq       150

# %%
df.Class=df.Class.astype('category')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True) 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std      17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min      26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%      46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%      58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%      72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max     129.834041   49.431864  125.742385  121.429566  163.071041  418.543082

# %% [markdown]
# # Univariate Analysis

# %%
#subplot(1)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('distplot')
sns.distplot(df['P_incidence'],color='red');
plt.subplot(1,2,2)
plt.title('boxplot')
sns.boxplot(df['P_incidence'],orient='vertical',color='green');

#subplot(2)
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.title('distplot')
sns.distplot(df['P_tilt'],color='red');
plt.subplot(1,2,2)
plt.title('boxplot')
sns.boxplot(df['P_tilt'],orient='vertical',color='green');


#sublot(3)
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.title('distplot')
sns.distplot(df['L_angle'],color='red');
plt.subplot(1,2,2)
plt.title('boxplot')
sns.boxplot(df['L_angle'],orient='vertical',color='green');


#subplot(4)
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.title('distplot')
sns.distplot(df['S_slope'],color='red');
plt.subplot(1,2,2)
plt.title('boxplot')
sns.boxplot(df['S_slope'],orient='vertical',color='green');

#Subplot(5)
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.title('distplot')
sns.distplot(df['P_radius'],color='red');
plt.subplot(1,2,2)
plt.title('boxplot')
sns.boxplot(df['P_radius'],orient='vertical',color='green');

#subplot(6)
plt.figure(figsize=(20,7))
plt.subplot(1,2,1)
plt.title('distplot')
sns.distplot(df['S_Degree'],color='red');
plt.subplot(1,2,2)
plt.title('boxplot')
sns.boxplot(df['S_Degree'],orient='vertical',color='green');

plt.show()

# %%
plt.figure(figsize=(4,4))
plt.title('Class')
sns.countplot(df['Class'],color='Blue');

plt.show()

# %%
df['Class'].value_counts().plot.pie( shadow=True,explode=(0.1, 0.1, 0.1),autopct='%.0f%%');

plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.title('P_incidence')
sns.boxplot(x='Class',y='P_incidence',data=df  );

plt.subplot(1,3,2)
plt.title('P_tilt')
sns.boxplot(x='Class',y='P_tilt',data=df  );

plt.subplot(1,3,3)
plt.title('L_angle')
sns.boxplot(x='Class',y='L_angle',data=df  );

plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.title('S_slope')
sns.boxplot(x='Class',y='S_slope',data=df );

plt.subplot(1,3,2)
plt.title('P_radius')
sns.boxplot(x='Class',y='P_radius',data=df );

plt.subplot(1,3,3)
plt.title('S_Degree')
sns.boxplot(x='Class',y='S_Degree',data=df  );

plt.show()

# %% [markdown]
# ##  Multivariate Analysis

# %%
sns.pairplot(df ,y_vars='Class', x_vars=['P_incidence','P_tilt','L_angle','S_slope','P_radius','S_Degree']);

# %% [markdown]
# # Data Pre-processing

# %%
col=['P_incidence','P_tilt','L_angle','S_slope','P_radius','S_Degree']
for c in col:
    q25,q75=np.percentile(df[c],25),np.percentile(df[c],75)
    IQR=q75-q25
    Threshold=IQR*1.5
    lower,upper=q25-Threshold,q75+Threshold
    Outliers=[x for x in df[c] if x < lower or x > upper]
    print('{} Total Number of outliers in {} : {}'.format('\033[1m',c,len(Outliers)))
    print('\n')
# Out:
#  Total Number of outliers in P_incidence : 3
#
#
#  Total Number of outliers in P_tilt : 13
#
#
#  Total Number of outliers in L_angle : 1
#
#
#  Total Number of outliers in S_slope : 1
#
#
#  Total Number of outliers in P_radius : 11
#
#
#  Total Number of outliers in S_Degree : 10

# %% [markdown]
# #  Target Imbalance

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.title('Class_percent')
df['Class'].value_counts().plot.pie(subplots=True,autopct='%.0f%%');

plt.subplot(1,3,2)
plt.title('Class_counts')
sns.countplot(df['Class'],color='Blue');plt.figure(figsize=(4,4))

plt.show()

# %% [markdown]
# # Hypothesis Testing

# %%
from scipy import stats 
from scipy.stats import f_oneway


col=['P_incidence','P_tilt','L_angle','S_slope','P_radius','S_Degree']
for i in col:
    df_normal=df[df.Class=='Normal'][i]
    df_typeH=df[df.Class=='Type_H'][i]
    df_typeS=df[df.Class=='Type_S'][i]
    f_stats,p_value=stats.f_oneway(df_normal,df_typeH,df_typeS)
    print('{} f_stats {}'.format('\033[1m',f_stats))
    print('{} p_value {}'.format('\033[1m',p_value))

    if p_value < 0.05:  # Setting our significance level at 5%
        print('{} Rejecting Null Hypothesis.Class types has efect on {}'.format('\033[1m',i))
    else:
        print('{} Fail to Reject Null Hypothesis.Class types has no effect on {}'.format('\033[1m',i))
    print('\n')
# Out:
#  f_stats 98.53970917437489
#  p_value 8.752848964938295e-34
#  Rejecting Null Hypothesis.Class types has efect on P_incidence
#
#
#  f_stats 21.29919432898912
#  p_value 2.176879152985521e-09
#  Rejecting Null Hypothesis.Class types has efect on P_tilt
#
#
#  f_stats 114.98284047330316
#  p_value 5.357329394004833e-38
#  Rejecting Null Hypothesis.Class types has efect on L_angle
#
#
#  f_stats 89.64395329777523
#  p_value 2.175670364983569e-31
#  Rejecting Null Hypothesis.Class types has efect on S_slope
#
#
#  f_stats 16.86693475538487
#  p_value 1.1219959042394205e-07
#  Rejecting Null Hypothesis.Class types has efect on P_radius
#
#
#  f_stats 119.12288060759808
#  p_value 5.1147320770401214e-39
#  Rejecting Null Hypothesis.Class types has efect on S_Degree

# %% [markdown]
# # Correlation

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True);

# %% [markdown]
# # Train - Test Split

# %%
from scipy.stats import zscore 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %%
x=df.drop(columns='Class')
y=df['Class']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=1)

# %%
x_scaled=x.apply(zscore)
x_scaled.describe().T
# Out:
#              count          mean       std       min       25%       50%  \
# P_incidence  310.0 -8.559461e-17  1.001617 -1.996010 -0.817398 -0.104925
# P_tilt       310.0  2.222237e-16  1.001617 -2.411664 -0.688114 -0.118606
# L_angle      310.0  3.137275e-16  1.001617 -2.047652 -0.806027 -0.127862
# S_slope      310.0 -1.493429e-16  1.001617 -2.207741 -0.716842 -0.040960
# P_radius     310.0 -5.624533e-16  1.001617 -3.597963 -0.542383  0.026138
# S_Degree     310.0 -5.228792e-17  1.001617 -0.996172 -0.658507 -0.387450
#
#                   75%        max
# P_incidence  0.719464   4.029206
# P_tilt       0.458116   3.191402
# L_angle      0.597549   3.984615
# S_slope      0.726941   5.855771
# P_radius     0.567621   3.395818
# S_Degree     0.399768  10.460350

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import classification_report
from sklearn import metrics

# %% [markdown]
# # KNN Model

# %%
KNN = KNeighborsClassifier(n_neighbors= 5 , metric = 'euclidean' )
KNN.fit(x_train, y_train)
KNN_pred = KNN.predict(x_test)

# %% [markdown]
# # Accuracy Of the KNN Model

# %%
print('Accuracy on Training data:',KNN.score(x_train, y_train) )
print('Accuracy on Test data:',KNN.score(x_test, y_test) )
# Out:
# Accuracy on Training data: 0.8940092165898618
# Accuracy on Test data: 0.8172043010752689

# %% [markdown]
# # Confusion Matrix for KNN Model

# %%
sns.heatmap(confusion_matrix(y_test,KNN_pred),annot=True,fmt='g');

# %% [markdown]
# # Classification Report

# %%
print("classification  Matrix:\n",classification_report(y_test,KNN_pred))
# Out:
# classification  Matrix:
#                precision    recall  f1-score   support
#
#       Normal       0.68      0.75      0.71        28
#       Type_H       0.62      0.59      0.61        17
#       Type_S       0.98      0.94      0.96        48
#
#     accuracy                           0.82        93
#    macro avg       0.76      0.76      0.76        93
# weighted avg       0.82      0.82      0.82        93

# %% [markdown]
# # Conclusion and improvisation

# %% [markdown]
# ### All the variables has significant effect on target class
# ### class type_s has higher percentage of alomst all Classes
# ### Class Type_normal has lower percentage of all classes.
# ### For almost all variables the distribution is normal
# ### We can use KNN as a final model as recall and precision values are good
# ### if Clear description on each Diseases have been given than we can train model more efficient.
# ### if Class Type_normal is patients normal condition than we can exclude it and come closer to more conclutive ways.
